# %% [markdown]
# # ÖDEV-7
# ## Ad Soyad : Muhammed Cemal Eryiğit
# ### Öğrenci No : 1801022024

# %% [markdown]
# ### Ön hazırlık dosyasında verilen kodlar aşağıya yazılacak:

# %% [markdown]
# # Ornek 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sgnl
from scipy.fftpack import fft, ifft
from scipy.io import loadmat
import SystemFunction
from scipy.io import loadmat
# %matplotlib notebook

# %%
N=400
M=60
n=np.arange(0,M+1,1)
wn=0.54-0.46*np.cos(2*np.pi*n/M)
x1=wn*np.cos(0.2*np.pi*n)
x2=wn*np.cos(0.4*np.pi*n-np.pi/2)
x3=wn*np.cos(0.8*np.pi*n-np.pi/5)
xn=np.concatenate((x3, x1, x2, np.zeros(N-3*len(n))), axis=None)
plt.figure()
plt.plot(xn)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
w=np.linspace(-np.pi,np.pi,N)
Xw=fft(xn)
Xw_shifted = np.fft.fftshift(Xw)
Hw,polezz,zerozz,K=SystemFunction.SystemFunction(w)
Hw_mag =abs(Hw)
Hw_phs = np.unwrap(np.angle(Hw))
fig,(ax1,ax2)=plt.subplots(2)
ax1.plot(w/np.pi,Hw_mag)
ax2.plot(w/np.pi,Hw_phs)
plt.ylabel('degrees')
plt.xlabel('frequency x$\pi$ red/sample')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tau_w = -np.diff(Hw_phs)*(N/(2*np.pi))
plt.figure()
plt.plot(w[1::]/np.pi,tau_w)
plt.ylabel('samples'), plt.xlabel('frequency x$\pi$ rad/sample')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Yw_shifted= Hw * Xw_shifted
Yw = np.fft.ifftshift(Yw_shifted)
yn = np.real(ifft(Yw))
fig, (ax1,ax2) = plt.subplots(2)
ax1.plot(xn)
ax2.plot(yn)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Ornek 3

# %%
N=40
hn=np.ones(5)
Hw=np.fft.fftshift(fft(hn,N))
w=np.linspace(-np.pi,np.pi,N)
Hw_mag = abs(Hw)
Hw_phs=np.unwrap(np.angle(Hw))
fig, (ax1, ax2) = plt.subplots(2)
ax1.plot(w/np.pi,Hw_mag)
ax2.plot(w/np.pi,Hw_phs)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tau_w =-np.diff(Hw_phs)*(N/2*np.pi)
plt.figure()
plt.plot(w[1::]/np.pi,tau_w)
plt.xlabel('frequency')
plt.ylabel('samples')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'samples')

# %%
n=np.arange(0,N,1)
w0=0.1*np.pi
xn = np.cos(w0*n)
Xw=np.fft.fftshift(fft(xn,N))
Yw_shifted = Hw * Xw
Yw = np.fft.ifftshift(Yw_shifted)
yn=np.real(ifft(Yw))
fig, (ax1,ax2) =plt.subplots(2)
ax1.stem(n,xn) , ax1.title.set_text('input signal')
ax2.stem(n,yn) , ax2.title.set_text('output signal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (<StemContainer object of 3 artists>, None)

# %% [markdown]
# # Ornek 4

# %%
filter_data = loadmat('butterworth.mat')
Coeffs = filter_data['ba'].astype(np.float)
b = Coeffs[:,0]
a = Coeffs[:,1]
w, Hw=sgnl.freqz(b,a)
Hw_mag = abs(Hw)
Hw_phs = np.unwrap(np.angle(Hw))
fig, (ax1,ax2)=plt.subplots(2)
ax1.plot(w/np.pi, Hw_mag)
ax2.plot(w/np.pi, Hw_phs) 
plt.ylabel('degrees')
plt.xlabel('frequency x$\pi$')
# Out:
# C:\Users\Cemal\AppData\Local\Temp/ipykernel_3436/3522340756.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Coeffs = filter_data['ba'].astype(np.float)
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'frequency x$\\pi$')

# %%
n, hn=sgnl.dimpulse ((b,a,1),n=100)
plt.figure()
plt.plot(n,np.squeeze((hn)))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
N=400
M=60
n=np.arange(0,M+1,1)
wn=0.54-0.46*np.cos(2*np.pi*n/M)
x1=wn*np.cos(0.2*np.pi*n)
x2=wn*np.cos(0.4*np.pi*n-np.pi/2)
x3=wn*np.cos(0.8*np.pi*n-np.pi/5)
xn=np.concatenate((x3, x1, x2, np.zeros(N-3*len(n))), axis=None)
plt.figure()
plt.plot(xn)
yn=sgnl.lfilter(b,a,xn)
plt.figure()
plt.plot(yn)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Ön hazırlık ödevleri (ÖDEV-7 başlığı altındaki soruların çözümleri aşağıda verilecek)

# %% [markdown]
# # SORU-1

# %%
# LOW PASS FILTER
filter_data = loadmat('FIR_LPF.mat')
Coeffs = filter_data['ba'].astype(np.float)
b = Coeffs[:,0]
w, Hw=sgnl.freqz(b,1)
Hw_mag = abs(Hw)
Hw_phs = np.unwrap(np.angle(Hw))
fig, (ax1,ax2)=plt.subplots(2)
ax1.plot(w/np.pi, Hw_mag)
ax2.plot(w/np.pi, Hw_phs) 
plt.ylabel('degrees')
plt.xlabel('frequency x$\pi$')
# Out:
# C:\Users\Cemal\AppData\Local\Temp/ipykernel_3436/1444600054.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Coeffs = filter_data['ba'].astype(np.float)
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'frequency x$\\pi$')

# %% [markdown]
# ![](FIR_LPF.jpg)

# %%
# BAND PASS FILTER
filter_data = loadmat('FIR_BPF.mat')
Coeffs = filter_data['ba'].astype(np.float)
b = Coeffs[:,0]
#a = Coeffs[1,:]
w, Hw=sgnl.freqz(b,1)
Hw_mag = abs(Hw)
Hw_phs = np.unwrap(np.angle(Hw))
fig, (ax1,ax2)=plt.subplots(2)
ax1.plot(w/np.pi, Hw_mag)
ax2.plot(w/np.pi, Hw_phs) 
plt.ylabel('degrees')
plt.xlabel('frequency x$\pi$')
# Out:
# C:\Users\Cemal\AppData\Local\Temp/ipykernel_3436/1932574697.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Coeffs = filter_data['ba'].astype(np.float)
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'frequency x$\\pi$')

# %% [markdown]
# ![](FIR_LPF.jpg)

# %% [markdown]
# ## FIR filtrelerde faz lineer olduğu için grup gecikmesi sabittir. Fazları sabit alçak geçiren filtre ve band geçiren filtre band genişlikleri en az 0.3 $ \pi$ olacak şekilde ayarlandı

# %% [markdown]
# # SORU-2

# %%
filter_data = loadmat('IIR_HPF.mat')
Coeffs = filter_data['ba'].astype(np.float)
b = Coeffs[:,0]
a = Coeffs[1,:]
w, Hw=sgnl.freqz(b,a)
Hw_mag = abs(Hw)
Hw_phs = np.unwrap(np.angle(Hw))
fig, (ax1,ax2)=plt.subplots(2)
ax1.plot(w/np.pi, Hw_mag)
ax2.plot(w/np.pi, Hw_phs) 
plt.ylabel('degrees')
plt.xlabel('frequency x$\pi$')
# Out:
# C:\Users\Cemal\AppData\Local\Temp/ipykernel_3436/559526474.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Coeffs = filter_data['ba'].astype(np.float)
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'frequency x$\\pi$')

# %% [markdown]
# ![](IIR_HPF.jpg)

# %%
filter_data = loadmat('IIR_LPF.mat')
Coeffs = filter_data['ba'].astype(np.float)
b = Coeffs[:,0]
a = Coeffs[1,:]
w, Hw=sgnl.freqz(b,a)
Hw_mag = abs(Hw)
Hw_phs = np.unwrap(np.angle(Hw))
fig, (ax1,ax2)=plt.subplots(2)
ax1.plot(w/np.pi, Hw_mag)
ax2.plot(w/np.pi, Hw_phs) 
plt.ylabel('degrees')
plt.xlabel('frequency x$\pi$')
# Out:
# C:\Users\Cemal\AppData\Local\Temp/ipykernel_3436/3187167584.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Coeffs = filter_data['ba'].astype(np.float)
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'frequency x$\\pi$')

# %% [markdown]
# ![](IIR_LPF.jpg)

# %% [markdown]
# ## IIR filtrelerde faz lineer olmadığı için grup gecikmesi sabit değildir. Fazları sabit olmayan alçak geçiren ve yüksek geçiren filtreler band genişlikleri en az 0.3 $ \pi$ olacak şekilde ayarlandı. Sabit olmayan grup gecikmeleri görsel olarak eklendi.
